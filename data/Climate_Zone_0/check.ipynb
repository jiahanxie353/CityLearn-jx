# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_1 = pd.read_csv("Building_1.csv")
df_2 = pd.read_csv("Building_2.csv")
df_3 = pd.read_csv("Building_3.csv")
df_4 = pd.read_csv("Building_4.csv")
df_5 = pd.read_csv("Building_5.csv")
df_6 = pd.read_csv("Building_6.csv")
df_7 = pd.read_csv("Building_7.csv")
df_8 = pd.read_csv("Building_8.csv")
df_9 = pd.read_csv("Building_9.csv")

# %%
df_15 = pd.read_csv("../Climate_Zone_5/Building_1.csv")
df_25 = pd.read_csv("../Climate_Zone_5/Building_2.csv")
df_35 = pd.read_csv("../Climate_Zone_5/Building_3.csv")
df_45 = pd.read_csv("../Climate_Zone_5/Building_4.csv")
df_55 = pd.read_csv("../Climate_Zone_5/Building_5.csv")
df_65 = pd.read_csv("../Climate_Zone_5/Building_6.csv")
df_75 = pd.read_csv("../Climate_Zone_5/Building_7.csv")
df_85 = pd.read_csv("../Climate_Zone_5/Building_8.csv")
df_95 = pd.read_csv("../Climate_Zone_5/Building_9.csv")

# %%
print(df_1["Equipment Electric Power [kWh]"].sum()/df_1["DHW Heating [kWh]"].sum())
# Out:
# 0.04028763614463737

# %%
print(df_1["Cooling Load [kWh]"].sum() + df_1["DHW Heating [kWh]"].sum() + df_1["Equipment Electric Power [kWh]"].sum())
# Out:
# 257191991.92719808

# %%
sum15 = df_15["Cooling Load [kWh]"] + df_15["DHW Heating [kWh]"] + df_15["Equipment Electric Power [kWh]"]
whole_date_5 = df_15.index
slottime = whole_date_5
slotavg = sum15
plt.title('Zone 5 Building 1 Elec Consume Plot')
plt.xlabel('Time/year')
plt.ylabel('KWh')
plt.plot(slottime, slotavg)

# %%
sum1 = df_1["Cooling Load [kWh]"] + df_1["DHW Heating [kWh]"] + df_1["Equipment Electric Power [kWh]"]
whole_date = pd.date_range(start='01/01/2016', end='01/01/2020', freq='H')
slottime = whole_date[:-1]
slotavg = sum1
plt.title('Baker Lab Elec Consume Plot')
plt.xlabel('Time/year')
plt.ylabel('KWh')
plt.plot(slottime, slotavg)
plt.xticks(ticks=['2016-06-01 00:00:00','2017-06-01 00:00:00','2018-06-01 00:00:00','2019-06-01 00:00:00'], labels=['2016', '2017', '2018', '2019'])
# Out:
# ([<matplotlib.axis.XTick at 0x15c1f6970>,
# ...
#  [Text(16953.0, 0, '2016'),
#   Text(17318.0, 0, '2017'),
#   Text(17683.0, 0, '2018'),
#   Text(18048.0, 0, '2019')])

# %%
print(df_2["Cooling Load [kWh]"].sum() + df_2["DHW Heating [kWh]"].sum() + df_2["Equipment Electric Power [kWh]"].sum())
# Out:
# 110461240.54574944

# %%
sum25 = df_25["Cooling Load [kWh]"] + df_25["DHW Heating [kWh]"] + df_25["Equipment Electric Power [kWh]"]
whole_date_5 = df_25.index
slottime = whole_date_5
slotavg = sum25
plt.title('Zone 5 Building 2 Elec Consume Plot')
plt.xlabel('Time/year')
plt.ylabel('KWh')
plt.plot(slottime, slotavg)

# %%
sum2 = df_2["Cooling Load [kWh]"] + df_2["DHW Heating [kWh]"] + df_2["Equipment Electric Power [kWh]"]
whole_date = pd.date_range(start='01/01/2016', end='01/01/2020', freq='H')
slottime = whole_date[:-1]
slotavg = sum2
plt.title('Bard Elec Consume Plot')
plt.xlabel('Time/year')
plt.ylabel('KWh')
plt.plot(slottime, slotavg)

# %%
print(df_3["Cooling Load [kWh]"].sum() + df_3["DHW Heating [kWh]"].sum() + df_3["Equipment Electric Power [kWh]"].sum())
# Out:
# 352445914.2762344

# %%
sum3 = df_3["Cooling Load [kWh]"] + df_3["DHW Heating [kWh]"] + df_3["Equipment Electric Power [kWh]"]
whole_date = pd.date_range(start='01/01/2016', end='01/01/2020', freq='H')
slottime = whole_date[:-1]
slotavg = sum3
plt.title('Bradfield Elec Consume Plot')
plt.xlabel('Time/year')
plt.ylabel('KWh')
plt.plot(slottime, slotavg)

# %%
print(df_1["Cooling Load [kWh]"].sum() + df_1["DHW Heating [kWh]"].sum() + df_1["Equipment Electric Power [kWh]"].sum())
print(df_2["Cooling Load [kWh]"].sum() + df_2["DHW Heating [kWh]"].sum() + df_2["Equipment Electric Power [kWh]"].sum())
print(df_3["Cooling Load [kWh]"].sum() + df_3["DHW Heating [kWh]"].sum() + df_3["Equipment Electric Power [kWh]"].sum())
print(df_4["Cooling Load [kWh]"].sum() + df_4["DHW Heating [kWh]"].sum() + df_4["Equipment Electric Power [kWh]"].sum())
print(df_5["Cooling Load [kWh]"].sum() + df_5["DHW Heating [kWh]"].sum() + df_5["Equipment Electric Power [kWh]"].sum())
print(df_6["Cooling Load [kWh]"].sum() + df_6["DHW Heating [kWh]"].sum() + df_6["Equipment Electric Power [kWh]"].sum())
print(df_7["Cooling Load [kWh]"].sum() + df_7["DHW Heating [kWh]"].sum() + df_7["Equipment Electric Power [kWh]"].sum())
print(df_8["Cooling Load [kWh]"].sum() + df_8["DHW Heating [kWh]"].sum() + df_8["Equipment Electric Power [kWh]"].sum())
print(df_9["Cooling Load [kWh]"].sum() + df_9["DHW Heating [kWh]"].sum() + df_9["Equipment Electric Power [kWh]"].sum())
# Out:
# 257191991.92719808
# 110461240.54574944
# 352445914.2762344
# 34995409.273889266
# 256121927.88506174
# 48612926.855210036
# 166700021.46759763
# 41209677.55906633
# 388768650.2390003

# %%
print(df_1["Cooling Load [kWh]"].sum())
print(df_2["Cooling Load [kWh]"].sum())
print(df_3["Cooling Load [kWh]"].sum())
print(df_4["Cooling Load [kWh]"].sum())
print(df_5["Cooling Load [kWh]"].sum())
print(df_6["Cooling Load [kWh]"].sum())
print(df_7["Cooling Load [kWh]"].sum())
print(df_8["Cooling Load [kWh]"].sum())
print(df_9["Cooling Load [kWh]"].sum())
# Out:
# 10483504.973292358
# 6347061.582823968
# 11166474.173217123
# 1548830.9787419222
# 24441763.68248312
# 2741068.6912385607
# 7536296.837502033
# 1952342.0739930877
# 26824506.64317952

# %%
print(df_1["DHW Heating [kWh]"].sum())
print(df_2["DHW Heating [kWh]"].sum())
print(df_3["DHW Heating [kWh]"].sum())
print(df_4["DHW Heating [kWh]"].sum())
print(df_5["DHW Heating [kWh]"].sum())
print(df_6["DHW Heating [kWh]"].sum())
print(df_7["DHW Heating [kWh]"].sum())
print(df_8["DHW Heating [kWh]"].sum())
print(df_9["DHW Heating [kWh]"].sum())
# Out:
# 237154108.51965982
# 99957713.10082248
# 325230688.0992078
# 31716660.565941185
# 215428398.38392794
# 44008240.84968589
# 153274902.40259567
# 35479640.35675445
# 336507240.36246985

# %%
print(df_1["Equipment Electric Power [kWh]"].sum())
print(df_2["Equipment Electric Power [kWh]"].sum())
print(df_3["Equipment Electric Power [kWh]"].sum())
print(df_4["Equipment Electric Power [kWh]"].sum())
print(df_5["Equipment Electric Power [kWh]"].sum())
print(df_6["Equipment Electric Power [kWh]"].sum())
print(df_7["Equipment Electric Power [kWh]"].sum())
print(df_8["Equipment Electric Power [kWh]"].sum())
print(df_9["Equipment Electric Power [kWh]"].sum())
# Out:
# 9554378.434245901
# 4156465.8621029975
# 16048752.00380946
# 1729917.729206161
# 16251765.818650667
# 1863617.314285582
# 5888822.62749994
# 3777695.128318791
# 25436903.233350936

# %%
print(3*df_4["DHW Heating [kWh]"].sum() / df_55["DHW Heating [kWh]"].sum())
# Out:
# 713.0524954955423

# %%
print(df_5["Cooling Load [kWh]"].sum() / df_55["Cooling Load [kWh]"].sum())
# Out:
# 27.890628110027798

# %%
print(1.5*df_5["DHW Heating [kWh]"].sum() / df_55["DHW Heating [kWh]"].sum())
# Out:
# 2421.6256429156206

# %%
print(df_6["Cooling Load [kWh]"].sum() / df_65["Cooling Load [kWh]"].sum())
# Out:
# 3.0396518707069857

# %%
print(3*df_6["DHW Heating [kWh]"].sum() / df_65["DHW Heating [kWh]"].sum())
# Out:
# 991.7546725362866

# %%
print(df_7["Cooling Load [kWh]"].sum() / df_75["Cooling Load [kWh]"].sum())
# Out:
# 7.856956049185686

# %%
print(3*df_8["DHW Heating [kWh]"].sum() / df_85["DHW Heating [kWh]"].sum())
# Out:
# 800.2134606099378

# %%
print(df_8["Cooling Load [kWh]"].sum() / df_85["Cooling Load [kWh]"].sum())
# Out:
# 2.904427406095595

# %%
print(3*df_4["DHW Heating [kWh]"].sum() / df_55["DHW Heating [kWh]"].sum())

# %%
print(df_9["Cooling Load [kWh]"].sum() / df_95["Cooling Load [kWh]"].sum())
# Out:
# 33.44325319008003

# %%
print(3*df_9["DHW Heating [kWh]"].sum() / df_95["DHW Heating [kWh]"].sum())
# Out:
# 7584.930011929831

# %%
print(140*df_1["Equipment Electric Power [kWh]"].sum() / df_15["Equipment Electric Power [kWh]"].sum())
# Out:
# 1549.2352824793675

# %%
print(80*df_2["Equipment Electric Power [kWh]"].sum() / df_25["Equipment Electric Power [kWh]"].sum())
# Out:
# 1125.7891421744005

# %%
print(50*df_3["Equipment Electric Power [kWh]"].sum() / df_35["Equipment Electric Power [kWh]"].sum())
# Out:
# 3712.129518894072

# %%
print(75*df_4["Equipment Electric Power [kWh]"].sum() / df_45["Equipment Electric Power [kWh]"].sum())
# Out:
# 910.3943397686039

# %%
print(50*df_5["Equipment Electric Power [kWh]"].sum() / df_55["Equipment Electric Power [kWh]"].sum())
# Out:
# 2280.0881152904285

# %%
print(30*df_6["Equipment Electric Power [kWh]"].sum() / df_65["Equipment Electric Power [kWh]"].sum())
# Out:
# 153.86502734628348

# %%
print(40*df_7["Equipment Electric Power [kWh]"].sum() / df_75["Equipment Electric Power [kWh]"].sum())
# Out:
# 494.95917997695244

# %%
print(30*df_8["Equipment Electric Power [kWh]"].sum() / df_85["Equipment Electric Power [kWh]"].sum())
# Out:
# 444.211047651158

# %%
print(35*df_9["Equipment Electric Power [kWh]"].sum() / df_95["Equipment Electric Power [kWh]"].sum())
# Out:
# 2337.23071429752
