# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
carp_data = pd.read_csv('Carpenter Data June 2016 - May 2022.csv')

# %%
filt_chilled_water = (carp_data['pointTitle'] == 'Chilled Water')
frame_chilled_water = carp_data.loc[filt_chilled_water]
slottime = frame_chilled_water.slottime_GMT
slotavg = frame_chilled_water.slotavg
plt.title('Carpenter Hall Chilled Water Plot')
plt.xlabel('Time/year')
plt.ylabel('Chilled water flow/ton of refrigeration')
plt.plot(slottime, slotavg)
plt.xticks(['2016-06-02 00:00:00','2017-06-01 00:00:00','2018-06-01 00:00:00','2019-06-01 00:00:00','2020-06-01 00:00:00','2021-06-01 00:00:00', '2022-05-01 00:00:00'],['2016','2017','2018','2019','2020','2021','2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x123bffac0>,
#   <matplotlib.axis.XTick at 0x123bff6a0>,
#   <matplotlib.axis.XTick at 0x123bff220>,
#   <matplotlib.axis.XTick at 0x123c263a0>,
#   <matplotlib.axis.XTick at 0x123c26d90>,
#   <matplotlib.axis.XTick at 0x123c2a250>,
#   <matplotlib.axis.XTick at 0x123c26e50>],
#  [Text(0.0, 0, '2016'),
#   Text(348.0, 0, '2017'),
#   Text(685.0, 0, '2018'),
#   Text(1049.0, 0, '2019'),
#   Text(1408.0, 0, '2020'),
#   Text(1773.0, 0, '2021'),
#   Text(2107.0, 0, '2022')])

# %%
filt_electric = (carp_data['pointTitle'] == 'Electric')
frame_electric = carp_data.loc[filt_electric]
slottime = frame_electric.slottime_GMT
slotavg = frame_electric.slotavg
plt.title('Carpenter Hall Electric Plot')
plt.xlabel('Time/year')
plt.ylabel('Electric Demand/kW')
plt.plot(slottime, slotavg, c='green')
plt.xticks(
    ['2016-06-02 00:00:00', '2017-06-01 00:00:00', '2018-06-01 00:00:00', '2019-06-01 00:00:00', '2020-06-01 00:00:00',
     '2021-06-01 00:00:00', '2022-05-01 00:00:00'], ['2016', '2017', '2018', '2019', '2020', '2021', '2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x123a815e0>,
#   <matplotlib.axis.XTick at 0x123a815b0>,
#   <matplotlib.axis.XTick at 0x1234847c0>,
#   <matplotlib.axis.XTick at 0x12389e100>,
#   <matplotlib.axis.XTick at 0x12389e0a0>,
#   <matplotlib.axis.XTick at 0x12389ea30>,
#   <matplotlib.axis.XTick at 0x123a29730>],
#  [Text(0.0, 0, '2016'),
#   Text(360.0, 0, '2017'),
#   Text(723.0, 0, '2018'),
#   Text(1088.0, 0, '2019'),
#   Text(1454.0, 0, '2020'),
#   Text(1819.0, 0, '2021'),
#   Text(2153.0, 0, '2022')])

# %%
filt_steam = (carp_data['pointTitle'] == 'Steam')
frame_steam = carp_data.loc[filt_steam]
slottime = frame_steam.slottime_GMT
slotavg = frame_steam.slotavg
plt.title('Carpenter Hall Steam Plot')
plt.xlabel('Time/year')
plt.ylabel('Steam flow/(Lbs/Hr)')
plt.plot(slottime, slotavg, c = 'orange')
plt.xticks(['2016-06-03 00:00:00','2017-06-02 00:00:00','2018-06-01 00:00:00','2019-06-01 00:00:00','2020-06-01 00:00:00','2021-06-01 00:00:00', '2022-05-01 00:00:00'],['2016','2017','2018','2019','2020','2021','2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x123889d00>,
#   <matplotlib.axis.XTick at 0x1238898e0>,
#   <matplotlib.axis.XTick at 0x123889e20>,
#   <matplotlib.axis.XTick at 0x123e9d520>,
#   <matplotlib.axis.XTick at 0x123ea7460>,
#   <matplotlib.axis.XTick at 0x123ea7bb0>,
#   <matplotlib.axis.XTick at 0x123eb0340>],
#  [Text(1.0, 0, '2016'),
#   Text(359.0, 0, '2017'),
#   Text(720.0, 0, '2018'),
#   Text(1084.0, 0, '2019'),
#   Text(1450.0, 0, '2020'),
#   Text(1815.0, 0, '2021'),
#   Text(2149.0, 0, '2022')])
