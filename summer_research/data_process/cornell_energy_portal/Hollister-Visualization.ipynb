# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
hollister_data = pd.read_csv('Hollister Data June 2016 - May 2022.csv')

# %%
filt_chilled_water = (hollister_data['pointTitle'] == 'Chilled Water')
frame_chilled_water = hollister_data.loc[filt_chilled_water]
slottime = frame_chilled_water.slottime_GMT
slotavg = frame_chilled_water.slotavg
plt.title('Hollister Hall Chilled Water Plot')
plt.xlabel('Time/year')
plt.ylabel('Chilled water flow/ton of refrigeration')
plt.plot(slottime, slotavg)
plt.xticks(['2016-06-02 00:00:00','2017-06-01 00:00:00','2018-06-01 00:00:00','2019-06-01 00:00:00','2020-06-01 00:00:00','2021-06-01 00:00:00', '2022-05-01 00:00:00'],['2016','2017','2018','2019','2020','2021','2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x137f13460>,
#   <matplotlib.axis.XTick at 0x137f138e0>,
#   <matplotlib.axis.XTick at 0x137b040d0>,
#   <matplotlib.axis.XTick at 0x14043de20>,
#   <matplotlib.axis.XTick at 0x137f1b1c0>,
#   <matplotlib.axis.XTick at 0x137f19880>,
#   <matplotlib.axis.XTick at 0x137f02d30>],
#  [Text(0.0, 0, '2016'),
#   Text(350.0, 0, '2017'),
#   Text(702.0, 0, '2018'),
#   Text(1042.0, 0, '2019'),
#   Text(1408.0, 0, '2020'),
#   Text(1773.0, 0, '2021'),
#   Text(2107.0, 0, '2022')])

# %%
filt_electric = (hollister_data['pointTitle'] == 'Electric')
frame_electric = hollister_data.loc[filt_electric]
slottime = frame_electric.slottime_GMT
slotavg = frame_electric.slotavg
plt.title('Hollister Hall Electric Plot')
plt.xlabel('Time/year')
plt.ylabel('Electric Demand/kW')
plt.plot(slottime, slotavg, c='green')
plt.xticks(
    ['2016-06-02 00:00:00', '2017-06-01 00:00:00', '2018-06-01 00:00:00', '2019-06-01 00:00:00', '2020-06-01 00:00:00',
     '2021-06-01 00:00:00', '2022-05-01 00:00:00'], ['2016', '2017', '2018', '2019', '2020', '2021', '2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x140848b20>,
#   <matplotlib.axis.XTick at 0x140848a00>,
#   <matplotlib.axis.XTick at 0x140836d00>,
#   <matplotlib.axis.XTick at 0x1408597c0>,
#   <matplotlib.axis.XTick at 0x14088e220>,
#   <matplotlib.axis.XTick at 0x14088e970>,
#   <matplotlib.axis.XTick at 0x1408597f0>],
#  [Text(0.0, 0, '2016'),
#   Text(360.0, 0, '2017'),
#   Text(723.0, 0, '2018'),
#   Text(1088.0, 0, '2019'),
#   Text(1448.0, 0, '2020'),
#   Text(1800.0, 0, '2021'),
#   Text(2134.0, 0, '2022')])

# %%
filt_steam = (hollister_data['pointTitle'] == 'Steam')
frame_steam = hollister_data.loc[filt_steam]
slottime = frame_steam.slottime_GMT
slotavg = frame_steam.slotavg
plt.title('Hollister Hall Steam Plot')
plt.xlabel('Time/year')
plt.ylabel('Steam flow/(Lbs/Hr)')
plt.plot(slottime, slotavg, c = 'orange')
plt.xticks(['2016-06-03 00:00:00','2017-06-02 00:00:00','2018-06-01 00:00:00','2019-06-01 00:00:00','2020-06-01 00:00:00','2021-06-01 00:00:00', '2022-05-01 00:00:00'],['2016','2017','2018','2019','2020','2021','2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x1408c6c40>,
#   <matplotlib.axis.XTick at 0x1408c6b20>,
#   <matplotlib.axis.XTick at 0x140897d90>,
#   <matplotlib.axis.XTick at 0x1408d75e0>,
#   <matplotlib.axis.XTick at 0x1408d5070>,
#   <matplotlib.axis.XTick at 0x1408d5ac0>,
#   <matplotlib.axis.XTick at 0x14090a250>],
#  [Text(1.0, 0, '2016'),
#   Text(361.0, 0, '2017'),
#   Text(722.0, 0, '2018'),
#   Text(1086.0, 0, '2019'),
#   Text(1452.0, 0, '2020'),
#   Text(1817.0, 0, '2021'),
#   Text(2151.0, 0, '2022')])
