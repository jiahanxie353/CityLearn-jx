# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
snee_data = pd.read_csv('Snee Data Jan 2018 - May 2022.csv')

# %%
filt_chilled_water = (snee_data['pointTitle'] == 'Chilled Water')
frame_chilled_water = snee_data.loc[filt_chilled_water]
slottime = frame_chilled_water.slottime_GMT
slotavg = frame_chilled_water.slotavg
plt.title('Snee Hall Chilled Water Plot')
plt.xlabel('Time/year')
plt.ylabel('Chilled water flow/ton of refrigeration')
plt.plot(slottime, slotavg)
plt.xticks(['2018-01-01 00:00:00','2019-01-01 00:00:00','2020-01-01 00:00:00','2021-01-01 00:00:00', '2022-01-01 00:00:00'],['2018','2019','2020','2021','2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x14fc59250>,
# ...
#  [Text(1491.0, 0, '2018'),
#   Text(245.0, 0, '2019'),
#   Text(610.0, 0, '2020'),
#   Text(976.0, 0, '2021'),
#   Text(1338.0, 0, '2022')])

# %%
filt_cw_rm_outliers = frame_chilled_water.slotavg > 170
sub_frame_cw = frame_chilled_water.loc[filt_cw_rm_outliers]
sub_frame_cw
# Out:
#                      name         slottime_GMT slottype     slotavg  \
# 3252  SneeHall.CW.FP/TONS  2020-07-22 00:00:00        D  177.525438
# 3256  SneeHall.CW.FP/TONS  2020-07-23 00:00:00        D  192.923682
# 3260  SneeHall.CW.FP/TONS  2020-07-24 00:00:00        D  177.013844
# 3264  SneeHall.CW.FP/TONS  2020-07-25 00:00:00        D  172.898599
#
#          pointTitle
# 3252  Chilled Water
# 3256  Chilled Water
# 3260  Chilled Water
# 3264  Chilled Water

# %%
filt_electric = (snee_data['pointTitle'] == 'Electric')
frame_electric = snee_data.loc[filt_electric]
slottime = frame_electric.slottime_GMT
slotavg = frame_electric.slotavg
plt.title('Snee Hall Electric Plot')
plt.xlabel('Time/year')
plt.ylabel('Electric Demand/kW')
plt.plot(slottime, slotavg, c='green')
plt.xticks(['2018-01-01 00:00:00','2019-01-01 00:00:00','2020-01-01 00:00:00','2021-01-01 00:00:00', '2022-01-01 00:00:00'],['2018','2019','2020','2021','2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x14fcbc490>,
# ...
#  [Text(0.0, 0, '2018'),
#   Text(365.0, 0, '2019'),
#   Text(730.0, 0, '2020'),
#   Text(1096.0, 0, '2021'),
#   Text(1461.0, 0, '2022')])

# %%
filt_steam = (snee_data['pointTitle'] == 'Steam')
frame_steam = snee_data.loc[filt_steam]
slottime = frame_steam.slottime_GMT
slotavg = frame_steam.slotavg
plt.title('Snee Hall Steam Plot')
plt.xlabel('Time/year')
plt.ylabel('Steam flow/(Lbs/Hr)')
plt.plot(slottime, slotavg, c='orange')
plt.xticks(['2018-01-01 00:00:00','2019-01-01 00:00:00','2020-01-01 00:00:00','2021-01-01 00:00:00', '2022-01-01 00:00:00'],['2018','2019','2020','2021','2022'])
# Out:
# ([<matplotlib.axis.XTick at 0x14fd3faf0>,
# ...
#  [Text(0.0, 0, '2018'),
#   Text(364.0, 0, '2019'),
#   Text(728.0, 0, '2020'),
#   Text(1094.0, 0, '2021'),
#   Text(1459.0, 0, '2022')])
